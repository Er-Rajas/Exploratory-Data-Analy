# %% [markdown]
# ## <span style="font-weight: bold; text-decoration: underline; color: #2E8B57;">OBJECTIVE</span>
#
# Start with a dataset of your choice and perform EDA using libraries like pandas, numpy, and matplotlib or seaborn. Explore the data's characteristics, distributions, correlations, and outliers. Visualize your findings with histograms, scatter plots, and heatmaps to gain insights into the data.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("meirnizri/covid19-dataset")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Covid Data.csv',index_col=False)

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
# Get a statistical summary
print(df.describe())
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %%
print(df.describe())
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %%
print(df['DATE_DIED'].value_counts())
# Out:
# DATE_DIED
# 9999-99-99    971633
# 06/07/2020      1000
# 07/07/2020       996
# 13/07/2020       990
# 16/06/2020       979
#                ...
# 25/12/2020         1
# 01/01/2021         1
# 02/01/2021         1
# 07/01/2021         1
# 22/04/2021         1
# Name: count, Length: 401, dtype: int64

# %%
df.to_csv("updated_df.csv")

# %%
plt.hist(df["AGE"],bins=30, color = 'skyblue', edgecolor='black')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
# First check unique values
# Convert ICU values to numeric, excluding 97 and 99
df["ICU_1"] = pd.to_numeric(df["ICU"], errors='coerce')
df["ICU_1"] = df["ICU_1"].replace([97, 99], np.nan)

# Create plot
sns.countplot(data=df.dropna(), x='ICU_1', palette='Set2')
plt.title('ICU Admission Count')
plt.xlabel('ICU (1 = Admitted, 0 = Not Admitted)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\rajas\AppData\Local\Temp\ipykernel_23656\376298069.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df.dropna(), x='ICU_1', palette='Set2')

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix =numeric_df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm', fmt='.2f')
plt.title('Correaltion Matrix')
plt.show()

# %%
df['DIED'] = df['DATE_DIED'] != '9999-99-99'

sns.countplot(data=df, x='DIED', palette ='cool')
plt.title('Survival vs Death Count')
plt.xlabel("Died (True/False)")
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\rajas\AppData\Local\Temp\ipykernel_23656\2797323693.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='DIED', palette ='cool')

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='SEX',data=df, palette='pastel')
plt.title('Gender Distribution')
plt.xlabel('Sex (1 = Male, 2 = Female)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\rajas\AppData\Local\Temp\ipykernel_23656\3178758659.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='SEX',data=df, palette='pastel')

# %%
# Check data
df["ICU_1"] = pd.to_numeric(df["ICU"], errors='coerce')
df["ICU_1"] = df["ICU_1"].replace([97, 99], np.nan)

plt.figure(figsize=(8, 6))
sns.boxplot(x='ICU_1', y='AGE', data=df, palette='Set2')
plt.title('ICU Admission vs Age')
plt.xlabel('ICU (1=Admitted, 2=Not Admitted)')
plt.ylabel('Age')
plt.show()
# Out:
# C:\Users\rajas\AppData\Local\Temp\ipykernel_23656\3215623126.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='ICU_1', y='AGE', data=df, palette='Set2')

# %%
comorbidities = ['DIABETES', 'COPD', 'ASTHMA', 'HIPERTENSION', 'CARDIOVASCULAR', 'OBESITY']
death_rates = df[df['DIED'] == True][comorbidities].sum()

plt.figure(figsize=(10, 6))
death_rates.sort_values().plot(kind='barh', color='salmon')
plt.title('Deaths by Comorbidities')
plt.xlabel('Number of Deaths')
plt.ylabel('Comorbidities')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(df[df['DIED'] == True]['AGE'], fill=True, color='red', label='Died')
sns.kdeplot(df[df['DIED'] == False]['AGE'], fill=True, color='blue', label='Survived')
plt.title('Age Distribution of Deceased vs Survivors')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
df["ICU_1"] = pd.to_numeric(df["ICU"], errors='coerce')
df["ICU_1"] = df["ICU_1"].replace([97, 99], np.nan)
df["INTUBED_1"] = pd.to_numeric(df["INTUBED"], errors='coerce')
df["INTUBED_1"] = df["INTUBED_1"].replace([97, 99], np.nan)


plt.figure(figsize=(8, 6))
sns.countplot(x='INTUBED_1', hue='ICU_1', data=df, palette='viridis')
plt.title('Intubation and ICU Admission')
plt.xlabel('Intubated (1=Yes, 2=No)')
plt.ylabel('Count')
plt.legend(title='ICU')
plt.show()
